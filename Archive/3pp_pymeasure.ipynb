# %%
from pulse_3pp import *

if __name__ == "__main__":
    # npp (U negative, N and D positive)
    # U pulse at t=0, N pulse 5ns after U ends, D pulse 3ns after N ends
    data = run_3pp(
        u_amplitude=0.5,       # U pulse amplitude (will be negative)
        u_to_n_delay=500.0,      # Time between U end and N start
        nd_amplitude=0.5,      # N and D amplitude (same, will be positive)
        n_to_d_delay=100.0,      # Time between N end and D start
        polarity='npp',
        base_offset=0,
        pulse_width_ns=200.0,
        capture_width_ns=2000.0,
        record_length=10000,
        vdiv=0.2,
        save_directory='test_3pp',
        auto_trigger=True,
        save_plot=True,
        save_data=True,
        verbose=True,
        num_averages=4,
    )

    # Example 2: pnn (U positive, N and D negative)
    # data = run_3pp(
    #     u_amplitude=1.0,
    #     u_to_n_delay=100.0,
    #     nd_amplitude=0.5,
    #     n_to_d_delay=200.0,
    #     polarity='pnn',
    #     capture_width_ns=1000.0,
    #     record_length=1e6,
    #     auto_trigger=True,
    #     verbose=True,
    #     save_plot=False,
    #     save_data=True,
    # )

    # Parameter sweep example:
    # for u_to_n in [3.0, 5.0, 7.0]:
    #     for n_to_d in [1.0, 3.0, 5.0]:
    #         data = run_3pp(0.2, u_to_n, 0.2, n_to_d,
    #                        polarity='npp',
    #                        auto_trigger=True,
    #                        save_plot=False,
    #                        verbose=False)
# Out:
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 0.5V
# CH2: 2 pulse(s), 0.5V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\test_3pp
# Saved: data\test_3pp\3pp_npp_U0p50V_ND0p50V_011.csv
# Saved: data\test_3pp\3pp_npp_U0p50V_ND0p50V.png

# %%
import pandas as pd
testdf = pd.read_csv(r"C:\Users\petermeisenheimer\Shepherd\3pp_pnn_U1.0V_ND0.csv",skiprows=11)
testdf
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 testdf = pd.read_csv(r"C:\Users\petermeisenheimer\Shepherd\3pp_pnn_U1.0V_ND0.csv",skiprows=11)
#       3 testdf
#
# ...

# %%
from tds6604_driver import TDS6604
scope = TDS6604('GPIB0::2::INSTR')
# scope.trigger_state
# scope.acquisition_numavg_current
# scope.acquisition_numavg = 16

trigger_channel = 4
# scope.setup_edge_trigger(
#     source=f'CH{trigger_channel}',
#     level=0.45,
#     slope='RISE',
#     mode='NORMAL'
# )

scope.write(f"TRIGGER:A:LEVEL 0.45")
scope.write('*CLS')
