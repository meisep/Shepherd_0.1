# %%
import numpy as np
from pulse_3pp import *
from pulse_uduu_short import *

# %%
### single 3pp
if __name__ == "__main__":
    # npp (U negative, N and D positive)
    # U pulse at t=0, N pulse 5ns after U ends, D pulse 3ns after N ends
    data = run_3pp(
        u_amplitude=0.5,       # U pulse amplitude (will be negative)
        u_to_n_delay=500.0,      # Time between U end and N start
        nd_amplitude=0.5,      # N and D amplitude (same, will be positive)
        n_to_d_delay=100.0,      # Time between N end and D start
        polarity='npp',
        base_offset=0,
        pulse_width_ns=200.0,
        capture_width_ns=2000.0,
        record_length=10000,
        vdiv=0.02,
        save_directory='test_3pp',
        auto_trigger=True,
        save_plot=False,
        save_data=False,
        verbose=True,
        num_averages=4,
    )
# Out:
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 0.5V
# CH2: 2 pulse(s), 0.5V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)

# %%
### SQUINT
lowval = -1
highval = 0.2
for k in np.concatenate([np.arange(lowval, highval, 0.075), np.arange(highval, lowval, -0.075)]):
    if __name__ == "__main__":
        data = run_3pp(
            u_amplitude=1.0,
            u_to_n_delay=500.0,
            nd_amplitude=1.0,
            n_to_d_delay=200.0,
            polarity='npp',
            base_offset=k,
            pulse_width_ns=200.0,
            capture_width_ns=2000.0,
            record_length=10000,
            vdiv=0.05,
            save_directory='SP022/D1/squint3-cd20',
            auto_trigger=True,
            save_plot=False,
            save_data=True,
            verbose=True,
            num_averages=4,
        )
# Out:
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_001.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_002.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_003.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_004.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_005.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_006.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_007.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_008.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_009.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_010.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_011.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_012.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_013.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_014.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_015.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_016.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_017.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_018.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_019.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_020.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_021.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_022.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_023.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_024.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_025.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_026.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_027.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_028.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_029.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_030.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.0V
# CH2: 2 pulse(s), 1.0V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022_D1\squint3-cd20
# Saved: data\SP022_D1\squint3-cd20\3pp_npp_U1p00V_ND1p00V_031.csv

# %%
### SHMOO
for j in ['npp','pnn']:
    for i in np.arange(0.1,1.0,0.05):
        if __name__ == "__main__":
            data = run_3pp(
                u_amplitude=1.2,       # U pulse amplitude (will be negative)
                u_to_n_delay=500.0,      # Time between U end and N start
                nd_amplitude=i,      # N and D amplitude (same, will be positive)
                n_to_d_delay=100.0,      # Time between N end and D start
                polarity=j,
                base_offset=-0.33,
                pulse_width_ns=200.0,
                capture_width_ns=2000.0,
                record_length=10000,
                vdiv=0.05,
                save_directory='SP022/D1/shmoo1-cd20',
                auto_trigger=True,
                save_plot=False,
                save_data=True,
                verbose=True,
                num_averages=4,
            )
# Out:
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.1V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p10V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.15000000000000002V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p15V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.20000000000000004V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p20V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.25000000000000006V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p25V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.30000000000000004V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p30V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.3500000000000001V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p35V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.40000000000000013V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p40V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.45000000000000007V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p45V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.5000000000000001V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p50V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.5500000000000002V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p55V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.6000000000000002V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p60V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.6500000000000001V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p65V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.7000000000000002V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p70V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.7500000000000002V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p75V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.8000000000000002V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p80V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.8500000000000002V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p85V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.9000000000000002V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p90V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: npp, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.9500000000000003V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_npp_U1p20V_ND0p95V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.1V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p10V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.15000000000000002V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p15V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.20000000000000004V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p20V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.25000000000000006V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p25V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.30000000000000004V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p30V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.3500000000000001V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p35V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.40000000000000013V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p40V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.45000000000000007V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p45V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.5000000000000001V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p50V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.5500000000000002V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p55V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.6000000000000002V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p60V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.6500000000000001V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p65V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.7000000000000002V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p70V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.7500000000000002V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p75V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.8000000000000002V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p80V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.8500000000000002V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p85V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.9000000000000002V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p90V.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pnn, Averages: 4
# CH1: 1 pulse(s), 1.2V
# CH2: 2 pulse(s), 0.9500000000000003V
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
# Captured: 10000 points (averaged over 4)
# Using directory: data\SP022\D1\shmoo1-cd20
# Saved: data\SP022\D1\shmoo1-cd20\3pp_pnn_U1p20V_ND0p95V.csv

# %%
# Example usage
if __name__ == "__main__":
    data = run_uduu(
        pulse_amplitude=0.5,      # 500 mV for all pulses
        pulse_width_ns=200.0,     # 200 ns pulse width
        u_to_d_delay=200.0,       # 500 ns between U1 and D
        d_to_u_delay=1e5,      # ns delay between D and U2
        u_to_u_delay=200.0,
        base_offset=-0.33,
        polarity='pp',           # pnpp
        capture_width_ns=1000.0,  # 1 µs capture window for final 2 U pulses
        save_directory='test_uduu',
        vdiv=0.05,
        auto_trigger=True,
        save_data=False,
        save_plot=False,
        verbose=True,
        num_averages=4,
    )
# Out:
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pp
# CH1: 3 pulse(s), 0.5V, inverted=False
# CH2: 1 pulse(s), 0.5V, inverted=True
# Scope averaging enabled: 4 acquisitions
# Scope: 200.0 ns/div, 10000 points, 4x averaging
#
# Average 1/4
#
# Average 2/4
#
# Average 3/4
#
# Average 4/4
# Captured: 10000 points, -0.031 to 0.035 V

# %%
## short time retention
for j in ['pp','nn']:
    for i in [1e3,1e4]:
        for k in [-0.16]: #set offset
        # for k in np.arange(-1,-0.2,0.05): #set offset
            if __name__ == "__main__":
                data = run_uduu(
                    pulse_amplitude=1.2,      # 500 mV for all pulses
                    pulse_width_ns=200.0,     # 200 ns pulse width
                    u_to_d_delay=200.0,       # 200 ns between U1 and D
                    d_to_u_delay=i,      # ns delay between D and U2
                    u_to_u_delay=200.0,
                    base_offset=k,
                    polarity=j,           # pp or nn
                    capture_width_ns=1000.0,
                    vdiv=0.05,
                    save_directory='SP022/D1/ret3-cd20',
                    auto_trigger=True,
                    save_data=True,
                    save_plot=False,
                    verbose=True
                )
                time.sleep(2)
# Out:
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pp
# CH1: 3 pulse(s), 1.2V, inverted=False
# CH2: 1 pulse(s), 1.2V, inverted=True
# Scope: 200.0 ns/div, 10000 points, 1x averaging
# Captured: 10000 points, -0.092 to 0.116 V
# Using directory: data\SP022\D1\ret3-cd20
# Saved: data\SP022\D1\ret3-cd20\uduu_pp_A1p2V_DU1000p0ns.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: pp
# CH1: 3 pulse(s), 1.2V, inverted=False
# CH2: 1 pulse(s), 1.2V, inverted=True
# Scope: 200.0 ns/div, 10000 points, 1x averaging
# Captured: 10000 points, -0.090 to 0.114 V
# Using directory: data\SP022\D1\ret3-cd20
# Saved: data\SP022\D1\ret3-cd20\uduu_pp_A1p2V_DU10000p0ns.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: nn
# CH1: 3 pulse(s), 1.2V, inverted=True
# CH2: 1 pulse(s), 1.2V, inverted=False
# Scope: 200.0 ns/div, 10000 points, 1x averaging
# Captured: 10000 points, -0.112 to 0.098 V
# Using directory: data\SP022\D1\ret3-cd20
# Saved: data\SP022\D1\ret3-cd20\uduu_nn_A1p2V_DU1000p0ns.csv
# Connected to: ACTIVE TECHNOLOGIES,AT-PULSE-RIDER-PG1072,00000001,SCPI:99.0,SV:1.0.0.0
# Connected to: TEKTRONIX,TDS6604,B010466,CF:91.1CT FV:2.5.3
# Polarity: nn
# CH1: 3 pulse(s), 1.2V, inverted=True
# CH2: 1 pulse(s), 1.2V, inverted=False
# Scope: 200.0 ns/div, 10000 points, 1x averaging
# Captured: 10000 points, -0.114 to 0.096 V
# Using directory: data\SP022\D1\ret3-cd20
# Saved: data\SP022\D1\ret3-cd20\uduu_nn_A1p2V_DU10000p0ns.csv
